# %%
#project ideas
#job market analyze
#restaurants
#booking.com
#comparing phones

# %%
import pandas as pd
from selenium import webdriver

# %%
browser = webdriver.Chrome()

# %%
url = "http://rate.am/en/armenian-dram-exchange-rates/banks/non-cash"

# %%
browser.get(url) #will wait untl page is fully loaded

# %%
browser.find_element_by_xpath("//label[contains(.,'Non-cash')]")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c8c3d930fb01a0cb1ddb807814f9a523", element="0.5216965947779535-1")>

# %%
browser.current_url
# Out:
# 'http://rate.am/en/armenian-dram-exchange-rates/banks/non-cash'

# %%
page = browser.page_source

# %%
browser.close()

# %%
all_tables = pd.read_html(page)

# %%
all_tables[2]
# Out:
#                                                    0                       1   \
# 0                                                 NaN                    Bank
# 1                                                 Buy                    Sell
# 2                                                  1.         ArmBusinessBank
# 3                                                  2.           Converse Bank
# 4                                                  3.              Ameriabank
# 5                                                  4.             Artsakhbank
# 6                                                  5.       HSBC Bank Armenia
# 7                                                  6.                 Unibank
# 8                                                  7.      VTB Bank (Armenia)
# 9                                                  8.               Evocabank
# 10                                                 9.               Inecobank
# 11                                                10.                 ID Bank
# 12                                                11.     Byblos Bank Armenia
# 13                                                12.            ArmSwissBank
# 14                                                13.             Ardshinbank
# 15                                                14.              ARARATBANK
# 16                                                15.  ACBA-Credit Agricole..
# 17                                                16.             Mellat Bank
# 18                                                17.           ARMECONOMBANK
# 19  Choose the nearest branch for you and save you...                     NaN
# 20                                            Minimum                     478
# 21                                            Maximum                  479.75
# 22                                            Average                  479.13
# 23                               Fluctuation (Jul 18)                   +0.22
#
#           2       3                                                  4   \
# 0   Branches    Date  1 USD \t1 EUR \t1 RUR \t1 GBP \t1 GEL \t1 CHF ...
# 1        Buy    Sell                                                Buy
# 2        NaN      55                                      19 Jul, 19:15
# 3        NaN      33                                      19 Jul, 19:15
# 4        NaN      11                                      19 Jul, 19:15
# 5        NaN      25                                      19 Jul, 19:15
# 6        NaN       7                                      19 Jul, 19:15
# 7        NaN      42                                      19 Jul, 19:15
# 8        NaN      69                                      19 Jul, 19:15
# 9        NaN      12                                      19 Jul, 19:15
# 10       NaN      23                                      19 Jul, 19:15
# 11       NaN      14                                      19 Jul, 19:15
# 12       NaN       5                                      19 Jul, 19:15
# 13       NaN       1                                      19 Jul, 19:15
# 14       NaN      53                                      19 Jul, 19:15
# 15       NaN      48                                      19 Jul, 19:15
# 16       NaN      59                                      19 Jul, 19:15
# 17       NaN       1                                      19 Jul, 19:15
# 18       NaN      51                                      19 Jul, 19:15
# 19       NaN     NaN                                                NaN
# 20    481.50     549                                                560
# 21    482.50     556                                                567
# 22       482  553.59                                             561.94
# 23     +0.20   -0.76                                              -1.02
#
#                                                    5   \
# 0   1 USD \t1 EUR \t1 RUR \t1 GBP \t1 GEL \t1 CHF ...
# 1                                                Sell
# 2                                              479.50
# 3                                              478.50
# 4                                                 479
# 5                                              479.75
# 6                                                 479
# 7                                              478.50
# 8                                              479.50
# 9                                              479.50
# 10                                             479.50
# 11                                                479
# 12                                                479
# 13                                             479.50
# 14                                             479.50
# 15                                             479.50
# 16                                                479
# 17                                                478
# 18                                                479
# 19                                                NaN
# 20                                               7.40
# 21                                               7.55
# 22                                               7.49
# 23                                              -0.04
#
#                                                    6   \
# 0   1 USD \t1 EUR \t1 RUR \t1 GBP \t1 GEL \t1 CHF ...
# 1                                                 Buy
# 2                                                 482
# 3                                                 482
# 4                                                 482
# 5                                                 482
# 6                                                 482
# 7                                                 482
# 8                                                 482
# 9                                                 482
# 10                                                482
# 11                                                482
# 12                                             482.50
# 13                                             481.50
# 14                                                482
# 15                                                482
# 16                                                482
# 17                                                482
# 18                                                482
# 19                                                NaN
# 20                                               7.64
# 21                                               7.90
# 22                                               7.71
# 23                                              -0.05
#
#                                                    7       8     9     10  \
# 0   1 USD \t1 EUR \t1 RUR \t1 GBP \t1 GEL \t1 CHF ...     NaN   NaN   NaN
# 1                                                Sell     NaN   NaN   NaN
# 2                                                 554  562.00  7.46  7.72
# 3                                                 552  560.00  7.49  7.69
# 4                                                 554  562.00  7.46  7.71
# 5                                                 555  562.00  7.51  7.70
# 6                                              553.50  560.50  7.45  7.68
# 7                                                 554  564.00  7.50  7.80
# 8                                                 555  560.00  7.55  7.66
# 9                                                 554  561.00  7.54  7.64
# 10                                             551.50  561.50  7.45  7.68
# 11                                                553  562.00  7.52  7.68
# 12                                                556  564.00  7.52  7.75
# 13                                                555  560.00  7.53  7.73
# 14                                                554  562.00  7.47  7.72
# 15                                                549  567.00  7.49  7.70
# 16                                                553  561.00  7.52  7.67
# 17                                                555  563.00  7.40  7.90
# 18                                                553  561.00  7.52  7.66
# 19                                                NaN     NaN   NaN   NaN
# 20                                                611  627.50   NaN   NaN
# 21                                                623  640.00   NaN   NaN
# 22                                             618.81  632.38   NaN   NaN
# 23                                              -2.27   -2.42   NaN   NaN
#
#        11     12
# 0     NaN    NaN
# 1     NaN    NaN
# 2   620.0  631.0
# 3   619.0  628.0
# 4   619.5  629.5
# 5   620.0  632.0
# 6   619.5  627.5
# 7   620.0  640.0
# 8   621.0  632.0
# 9   620.0  629.0
# 10  618.0  629.0
# 11  621.0  636.0
# 12  623.0  634.0
# 13  622.0  628.0
# 14  622.0  637.0
# 15  611.0  640.0
# 16  612.0  633.0
# 17    NaN    NaN
# 18  613.0  632.0
# 19    NaN    NaN
# 20    NaN    NaN
# 21    NaN    NaN
# 22    NaN    NaN
# 23    NaN    NaN

# %%
clean_table = all_tables[2].iloc[3:19, [i for i in range(13) if i ==1 or i <=5]]   #5:12

# %%
clean_table
# Out:
#                         1       5       6       7      8     9     10     11  \
# 3            Converse Bank  478.50     482     552  560.0  7.49  7.69  619.0
# 4               Ameriabank     479     482     554  562.0  7.46  7.71  619.5
# 5              Artsakhbank  479.75     482     555  562.0  7.51  7.70  620.0
# 6        HSBC Bank Armenia     479     482  553.50  560.5  7.45  7.68  619.5
# 7                  Unibank  478.50     482     554  564.0  7.50  7.80  620.0
# 8       VTB Bank (Armenia)  479.50     482     555  560.0  7.55  7.66  621.0
# 9                Evocabank  479.50     482     554  561.0  7.54  7.64  620.0
# 10               Inecobank  479.50     482  551.50  561.5  7.45  7.68  618.0
# 11                 ID Bank     479     482     553  562.0  7.52  7.68  621.0
# 12     Byblos Bank Armenia     479  482.50     556  564.0  7.52  7.75  623.0
# 13            ArmSwissBank  479.50  481.50     555  560.0  7.53  7.73  622.0
# 14             Ardshinbank  479.50     482     554  562.0  7.47  7.72  622.0
# 15              ARARATBANK  479.50     482     549  567.0  7.49  7.70  611.0
# 16  ACBA-Credit Agricole..     479     482     553  561.0  7.52  7.67  612.0
# 17             Mellat Bank     478     482     555  563.0  7.40  7.90    NaN
# 18           ARMECONOMBANK     479     482     553  561.0  7.52  7.66  613.0
#
#        12
# 3   628.0
# 4   629.5
# 5   632.0
# 6   627.5
# 7   640.0
# 8   632.0
# 9   629.0
# 10  629.0
# 11  636.0
# 12  634.0
# 13  628.0
# 14  637.0
# 15  640.0
# 16  633.0
# 17    NaN
# 18  632.0

# %%
browser = webdriver.Chrome()
browser.get(url)

# %%
from selenium.webdriver.common.keys import Keys

# %%
#Keys.END
button = browser.find_element_by_tag_name("html")

# %%
button.send_keys(Keys.PAGE_DOWN)

# %%
old = ""
new= " "
while new>old:
    old= browser.page_source
    button.send_keys(Keys.END)
    new = browser.page_source

# %%
browser.get("https://www.bloomberg.com/")

# %%
browser.implicitly_wait(15)
browser.find_element_by_partial_link_text("S&P")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1b894cf5f923b03361e523ce63df6ce5", element="0.5755035863750657-1")>

# %%
#expected condition
#EC(presense_of_element_located())
